# %% [markdown]
# <a href="https://colab.research.google.com/github/nashran-bakso/pemograman-dasar/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nama = "Nashran"
umur = 20
jurusan = "RPE"
semester = 3
matakuliah = 'Pemerograman Dasar'
status_lulus = True

print (nama)
print(umur)
print(jurusan)
print(semester)
print(matakuliah)
print(status_lulus)
# Out:
# Nashran
# 20
# RPE
# 3
# Pemerograman Dasar
# True
